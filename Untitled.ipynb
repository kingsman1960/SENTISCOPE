# %%
from sentiscope import SentimentAnalyzer, NewsFetcher, EntityExtractor

# Initialize components
sentiment_analyzer = SentimentAnalyzer()
news_fetcher = NewsFetcher(api_key="0cf5b245641b420ba8e54eb209004b6e")
entity_extractor = EntityExtractor()

# Fetch news
news = news_fetcher.fetch_financial_news("Banking")

# Analyze sentiment and extract entities
for article in news:
    finbert_sentiment = sentiment_analyzer.analyze_sentiment_finbert(article['description'])
    vader_sentiment = sentiment_analyzer.analyze_sentiment_vader(article['description'])
    entities = entity_extractor.extract_entities_flair(article['description'])
    
    print(f"Title: {article['title']}")
    print(f"FinBERT Sentiment: {finbert_sentiment}")
    print(f"VADER Sentiment: {vader_sentiment}")
    print(f"Entities: {entities}")
    print("---")
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\manne\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\manne\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package maxent_ne_chunker to
# [nltk_data]     C:\Users\manne\AppData\Roaming\nltk_data...
# [nltk_data]   Package maxent_ne_chunker is already up-to-date!
# [nltk_data] Downloading package words to
# [nltk_data]     C:\Users\manne\AppData\Roaming\nltk_data...
# [nltk_data]   Package words is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\manne\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# C:\Users\manne\anaconda3\envs\SENTISCOPE\Lib\site-packages\transformers\tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# 2024-09-26 00:44:01,350 SequenceTagger predicts: Dictionary with 20 tags: <unk>, O, S-ORG, S-MISC, B-PER, E-PER, S-LOC, B-ORG, E-ORG, I-PER, S-PER, B-MISC, I-MISC, E-MISC, I-ORG, B-LOC, E-LOC, I-LOC, <START>, <STOP>
# Title: 'I'm trapped in a joint mortgage with my abuser'
# FinBERT Sentiment: {'Negative': 0.1476445347070694, 'Neutral': 0.2286837100982666, 'Positive': 0.6236717700958252}
# VADER Sentiment: {'neg': 0.34, 'neu': 0.445, 'pos': 0.215, 'compound': -0.6249}
# Entities: []
# ---
# Title: Back-to-work scam warning after complaints hit peak
# FinBERT Sentiment: {'Negative': 0.00988619402050972, 'Neutral': 0.9433751702308655, 'Positive': 0.04673866182565689}
# VADER Sentiment: {'neg': 0.515, 'neu': 0.485, 'pos': 0.0, 'compound': -0.8934}
# Entities: []
# ---
# Title: Growing The Economy Through Investment Banking And Generative AI
# FinBERT Sentiment: {'Negative': 0.4225849509239197, 'Neutral': 0.011178059503436089, 'Positive': 0.5662369728088379}
# VADER Sentiment: {'neg': 0.0, 'neu': 0.809, 'pos': 0.191, 'compound': 0.3818}
# Entities: []
# ---
# Title: Modernizing African Banking: Unlocking Investment Potential
# FinBERT Sentiment: {'Negative': 0.07058151066303253, 'Neutral': 0.01902202144265175, 'Positive': 0.9103964567184448}
# VADER Sentiment: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Entities: []
# ---
# Title: The Game-Changing Advantage In Investment Banking
# FinBERT Sentiment: {'Negative': 0.08073781430721283, 'Neutral': 0.027852952480316162, 'Positive': 0.8914092183113098}
# VADER Sentiment: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Entities: []
# ---
# Title: 5 Top Stocks To Buy In October
# FinBERT Sentiment: {'Negative': 0.060647912323474884, 'Neutral': 0.01433416549116373, 'Positive': 0.9250178933143616}
# VADER Sentiment: {'neg': 0.0, 'neu': 0.85, 'pos': 0.15, 'compound': 0.5267}
# Entities: []
# ---
# Title: Goldman Sachs Plans To Lay Off Around 1,300 Employees
# FinBERT Sentiment: {'Negative': 0.00950164720416069, 'Neutral': 0.9674162864685059, 'Positive': 0.02308211289346218}
# VADER Sentiment: {'neg': 0.087, 'neu': 0.913, 'pos': 0.0, 'compound': -0.296}
# Entities: [('Goldman Sachs', 'ORG')]
# ---
# Title: Traditional Banks And Embedded Finance: Competitors Or Allies?
# FinBERT Sentiment: {'Negative': 0.8633639216423035, 'Neutral': 0.008247834630310535, 'Positive': 0.1283881962299347}
# VADER Sentiment: {'neg': 0.099, 'neu': 0.671, 'pos': 0.23, 'compound': 0.4019}
# Entities: []
# ---
# Title: It Is Time To Start Winding Down The Federal Home Loan Banking System
# FinBERT Sentiment: {'Negative': 0.039928335696458817, 'Neutral': 0.5049051642417908, 'Positive': 0.4551665186882019}
# VADER Sentiment: {'neg': 0.213, 'neu': 0.787, 'pos': 0.0, 'compound': -0.2263}
# Entities: []
# ---
# Title: Consumer Demands Outpacing Digital Offerings In Banking
# FinBERT Sentiment: {'Negative': 0.015618476085364819, 'Neutral': 0.9533331394195557, 'Positive': 0.031048374250531197}
# VADER Sentiment: {'neg': 0.0, 'neu': 0.833, 'pos': 0.167, 'compound': 0.6369}
# Entities: [('U.S.', 'LOC')]
# ---

# %%
# !pip install SENTISCOPE==0.2.1
# Out:
# Collecting SENTISCOPE==0.2.1
#   Downloading SENTISCOPE-0.2.1-py3-none-any.whl (4.8 kB)
# Requirement already satisfied: flair in c:\users\manne\anaconda3\lib\site-packages (from SENTISCOPE==0.2.1) (0.14.0)
# Requirement already satisfied: requests in c:\users\manne\anaconda3\lib\site-packages (from SENTISCOPE==0.2.1) (2.28.1)
# Requirement already satisfied: transformers in c:\users\manne\anaconda3\lib\site-packages (from SENTISCOPE==0.2.1) (4.24.0)
# Requirement already satisfied: torch in c:\users\manne\anaconda3\lib\site-packages (from SENTISCOPE==0.2.1) (1.13.0)
# Requirement already satisfied: nltk in c:\users\manne\appdata\roaming\python\python38\site-packages (from SENTISCOPE==0.2.1) (3.7)
# Requirement already satisfied: scikit-learn>=1.0.2 in c:\users\manne\anaconda3\lib\site-packages (from flair->SENTISCOPE==0.2.1) (1.1.3)
# Requirement already satisfied: segtok>=1.5.11 in c:\users\manne\anaconda3\lib\site-packages (from flair->SENTISCOPE==0.2.1) (1.5.11)
# Requirement already satisfied: bioc<3.0.0,>=2.0.0 in c:\users\manne\anaconda3\lib\site-packages (from flair->SENTISCOPE==0.2.1) (2.1)
# Requirement already satisfied: pptree>=3.1 in c:\users\manne\anaconda3\lib\site-packages (from flair->SENTISCOPE==0.2.1) (3.1)
# Requirement already satisfied: transformer-smaller-training-vocab>=0.2.3 in c:\users\manne\anaconda3\lib\site-packages (from flair->SENTISCOPE==0.2.1) (0.4.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\manne\anaconda3\lib\site-packages (from flair->SENTISCOPE==0.2.1) (2.8.2)
# Requirement already satisfied: matplotlib>=2.2.3 in c:\users\manne\anaconda3\lib\site-packages (from flair->SENTISCOPE==0.2.1) (3.7.1)
# Requirement already satisfied: mpld3>=0.3 in c:\users\manne\anaconda3\lib\site-packages (from flair->SENTISCOPE==0.2.1) (0.5.10)
# Requirement already satisfied: gdown>=4.4.0 in c:\users\manne\anaconda3\lib\site-packages (from flair->SENTISCOPE==0.2.1) (5.2.0)
# Requirement already satisfied: tabulate>=0.8.10 in c:\users\manne\anaconda3\lib\site-packages (from flair->SENTISCOPE==0.2.1) (0.9.0)
# Requirement already satisfied: sqlitedict>=2.0.0 in c:\users\manne\anaconda3\lib\site-packages (from flair->SENTISCOPE==0.2.1) (2.1.0)
# Requirement already satisfied: pytorch-revgrad>=0.2.0 in c:\users\manne\anaconda3\lib\site-packages (from flair->SENTISCOPE==0.2.1) (0.2.0)
# Requirement already satisfied: wikipedia-api>=0.5.7 in c:\users\manne\anaconda3\lib\site-packages (from flair->SENTISCOPE==0.2.1) (0.7.1)
# Requirement already satisfied: langdetect>=1.0.9 in c:\users\manne\anaconda3\lib\site-packages (from flair->SENTISCOPE==0.2.1) (1.0.9)
# Requirement already satisfied: regex>=2022.1.18 in c:\users\manne\anaconda3\lib\site-packages (from flair->SENTISCOPE==0.2.1) (2022.10.31)
# Requirement already satisfied: lxml>=4.8.0 in c:\users\manne\anaconda3\lib\site-packages (from flair->SENTISCOPE==0.2.1) (4.9.2)
# Requirement already satisfied: tqdm>=4.63.0 in c:\users\manne\anaconda3\lib\site-packages (from flair->SENTISCOPE==0.2.1) (4.64.1)
# Requirement already satisfied: conllu<5.0.0,>=4.0 in c:\users\manne\anaconda3\lib\site-packages (from flair->SENTISCOPE==0.2.1) (4.5.3)
# Requirement already satisfied: ftfy>=6.1.0 in c:\users\manne\anaconda3\lib\site-packages (from flair->SENTISCOPE==0.2.1) (6.2.3)
# Requirement already satisfied: huggingface-hub>=0.10.0 in c:\users\manne\anaconda3\lib\site-packages (from flair->SENTISCOPE==0.2.1) (0.10.1)
# Requirement already satisfied: semver<4.0.0,>=3.0.0 in c:\users\manne\anaconda3\lib\site-packages (from flair->SENTISCOPE==0.2.1) (3.0.2)
# Requirement already satisfied: boto3>=1.20.27 in c:\users\manne\anaconda3\lib\site-packages (from flair->SENTISCOPE==0.2.1) (1.28.43)
# Requirement already satisfied: deprecated>=1.2.13 in c:\users\manne\anaconda3\lib\site-packages (from flair->SENTISCOPE==0.2.1) (1.2.14)
# Requirement already satisfied: more-itertools>=8.13.0 in c:\users\manne\anaconda3\lib\site-packages (from flair->SENTISCOPE==0.2.1) (9.0.0)
# Requirement already satisfied: typing_extensions in c:\users\manne\anaconda3\lib\site-packages (from torch->SENTISCOPE==0.2.1) (4.5.0)
# Requirement already satisfied: click in c:\users\manne\anaconda3\lib\site-packages (from nltk->SENTISCOPE==0.2.1) (8.1.3)
# Requirement already satisfied: joblib in c:\users\manne\anaconda3\lib\site-packages (from nltk->SENTISCOPE==0.2.1) (1.1.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\manne\anaconda3\lib\site-packages (from requests->SENTISCOPE==0.2.1) (2.10)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\manne\anaconda3\lib\site-packages (from requests->SENTISCOPE==0.2.1) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\manne\anaconda3\lib\site-packages (from requests->SENTISCOPE==0.2.1) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\manne\anaconda3\lib\site-packages (from requests->SENTISCOPE==0.2.1) (1.26.6)
# Requirement already satisfied: packaging>=20.0 in c:\users\manne\anaconda3\lib\site-packages (from transformers->SENTISCOPE==0.2.1) (21.3)
# Requirement already satisfied: numpy>=1.17 in c:\users\manne\anaconda3\lib\site-packages (from transformers->SENTISCOPE==0.2.1) (1.24.3)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in c:\users\manne\anaconda3\lib\site-packages (from transformers->SENTISCOPE==0.2.1) (0.13.1)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\manne\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\manne\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\manne\anaconda3\lib\site-packages)
#     WARNING: Ignoring invalid distribution -atplotlib (c:\users\manne\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\manne\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\manne\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\manne\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\manne\anaconda3\lib\site-packages)
# Requirement already satisfied: filelock in c:\users\manne\anaconda3\lib\site-packages (from transformers->SENTISCOPE==0.2.1) (3.6.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\manne\anaconda3\lib\site-packages (from transformers->SENTISCOPE==0.2.1) (6.0)
# Requirement already satisfied: intervaltree in c:\users\manne\anaconda3\lib\site-packages (from bioc<3.0.0,>=2.0.0->flair->SENTISCOPE==0.2.1) (3.1.0)
# Requirement already satisfied: jsonlines>=1.2.0 in c:\users\manne\anaconda3\lib\site-packages (from bioc<3.0.0,>=2.0.0->flair->SENTISCOPE==0.2.1) (4.0.0)
# Requirement already satisfied: docopt in c:\users\manne\anaconda3\lib\site-packages (from bioc<3.0.0,>=2.0.0->flair->SENTISCOPE==0.2.1) (0.6.2)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in c:\users\manne\anaconda3\lib\site-packages (from boto3>=1.20.27->flair->SENTISCOPE==0.2.1) (1.0.1)
# Requirement already satisfied: botocore<1.32.0,>=1.31.43 in c:\users\manne\anaconda3\lib\site-packages (from boto3>=1.20.27->flair->SENTISCOPE==0.2.1) (1.31.43)
# Requirement already satisfied: s3transfer<0.7.0,>=0.6.0 in c:\users\manne\anaconda3\lib\site-packages (from boto3>=1.20.27->flair->SENTISCOPE==0.2.1) (0.6.2)
# Requirement already satisfied: wrapt<2,>=1.10 in c:\users\manne\anaconda3\lib\site-packages (from deprecated>=1.2.13->flair->SENTISCOPE==0.2.1) (1.13.3)
# Requirement already satisfied: wcwidth<0.3.0,>=0.2.12 in c:\users\manne\anaconda3\lib\site-packages (from ftfy>=6.1.0->flair->SENTISCOPE==0.2.1) (0.2.13)
# Requirement already satisfied: beautifulsoup4 in c:\users\manne\anaconda3\lib\site-packages (from gdown>=4.4.0->flair->SENTISCOPE==0.2.1) (4.11.1)
# Requirement already satisfied: six in c:\users\manne\anaconda3\lib\site-packages (from langdetect>=1.0.9->flair->SENTISCOPE==0.2.1) (1.16.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\manne\anaconda3\lib\site-packages (from matplotlib>=2.2.3->flair->SENTISCOPE==0.2.1) (1.0.6)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\manne\anaconda3\lib\site-packages (from matplotlib>=2.2.3->flair->SENTISCOPE==0.2.1) (4.25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\manne\anaconda3\lib\site-packages (from matplotlib>=2.2.3->flair->SENTISCOPE==0.2.1) (3.0.9)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\manne\anaconda3\lib\site-packages (from matplotlib>=2.2.3->flair->SENTISCOPE==0.2.1) (9.4.0)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\manne\anaconda3\lib\site-packages (from matplotlib>=2.2.3->flair->SENTISCOPE==0.2.1) (5.10.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\manne\anaconda3\lib\site-packages (from matplotlib>=2.2.3->flair->SENTISCOPE==0.2.1) (1.4.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\manne\anaconda3\lib\site-packages (from matplotlib>=2.2.3->flair->SENTISCOPE==0.2.1) (0.11.0)
# Requirement already satisfied: jinja2 in c:\users\manne\appdata\roaming\python\python38\site-packages (from mpld3>=0.3->flair->SENTISCOPE==0.2.1) (3.0.3)
# Requirement already satisfied: scipy>=1.3.2 in c:\users\manne\anaconda3\lib\site-packages (from scikit-learn>=1.0.2->flair->SENTISCOPE==0.2.1) (1.9.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\manne\anaconda3\lib\site-packages (from scikit-learn>=1.0.2->flair->SENTISCOPE==0.2.1) (3.1.0)
# Requirement already satisfied: colorama in c:\users\manne\anaconda3\lib\site-packages (from tqdm>=4.63.0->flair->SENTISCOPE==0.2.1) (0.4.5)
# Requirement already satisfied: sentencepiece!=0.1.92,>=0.1.91 in c:\users\manne\anaconda3\lib\site-packages (from transformers->SENTISCOPE==0.2.1) (0.2.0)
# Requirement already satisfied: protobuf<=3.20.2 in c:\users\manne\appdata\roaming\python\python38\site-packages (from transformers->SENTISCOPE==0.2.1) (3.19.6)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\manne\anaconda3\lib\site-packages (from importlib-resources>=3.2.0->matplotlib>=2.2.3->flair->SENTISCOPE==0.2.1) (3.8.0)
# Requirement already satisfied: attrs>=19.2.0 in c:\users\manne\anaconda3\lib\site-packages (from jsonlines>=1.2.0->bioc<3.0.0,>=2.0.0->flair->SENTISCOPE==0.2.1) (21.4.0)
# Requirement already satisfied: soupsieve>1.2 in c:\users\manne\anaconda3\lib\site-packages (from beautifulsoup4->gdown>=4.4.0->flair->SENTISCOPE==0.2.1) (2.3.2.post1)
# Requirement already satisfied: sortedcontainers<3.0,>=2.0 in c:\users\manne\anaconda3\lib\site-packages (from intervaltree->bioc<3.0.0,>=2.0.0->flair->SENTISCOPE==0.2.1) (2.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\manne\anaconda3\lib\site-packages (from jinja2->mpld3>=0.3->flair->SENTISCOPE==0.2.1) (2.1.1)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in c:\users\manne\anaconda3\lib\site-packages (from requests->SENTISCOPE==0.2.1) (1.7.1)
# Installing collected packages: SENTISCOPE
#   Attempting uninstall: SENTISCOPE
#     Found existing installation: SENTISCOPE 0.1.0
#     Uninstalling SENTISCOPE-0.1.0:
#       Successfully uninstalled SENTISCOPE-0.1.0
# Successfully installed SENTISCOPE-0.2.1
